# %% [markdown]
# # COFFEE COFFEE COFFEE data set loading
# ### Thomas Rosenthal

# %%
#required packages
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# '/Users/thomas/Documents/GitHub/COFFEE_COFFEE_COFFEE/scripts'

# %%
#specify your local path
os.chdir("../../Automatic_Drip/R")

# %%
#looping mechanism
#specify your local path
file_list = []
for dirname, _, filenames in os.walk("outputs/"):
    for filename in filenames:
        if '.csv' in filename:
            file_list.append(os.path.join(dirname, filename))

# %%
raw_data = (pd.concat(pd.read_csv(f, encoding='latin-1') for f in file_list))

# %%
raw_data.head
# Out:
#                   Roaster                                         CoffeeName  \
# 0   Pilot Coffee Roasters           Coffee Roasters  Catalan De Las Mercedes
# 1   Pilot Coffee Roasters            Coffee Roasters  Gachatha washed  Kenya
# 2   Pilot Coffee Roasters   Coffee Roasters  Las Palmas, El Volcan, Colombia
# 3   Pilot Coffee Roasters          Coffee Roasters  San JerÃ³nimo, Guatemala
# 4   Pilot Coffee Roasters  Coffee Roasters  Sumava De Lourdes, Kinkajou  ...
# ..                    ...                                                ...
# 45             Sey Coffee                                        El Porvenir
# 46             Sey Coffee                                           Putuchio
# 47             Sey Coffee                                            La Fila
# 48             Sey Coffee                                           Gaaki AA
# 49             Sey Coffee                                          El Casino
#
# ...
